# %%
import pandas as pd
df = pd.read_json('gender_articles.json')

# %%
df
# Out:
#                                                  title  \
# 0    United States v. Skrmetti: Oral Arguments Indi...
# 1    Trump’s Transgender Orders Are Well Within Exe...
# 2    Sorry Democrats, but Trump’s “Two Sexes” Execu...
# 3    Wisconsin Public Schools’ Gender Policies Shut...
# 4                                       Follow the Law
# ..                                                 ...
# 299  The Problems With CNN Poll Showing Opposition ...
# 300                                    Parents Beware!
# 301              Monogamy, Exclusivity and Permanence?
# 302  Anti-First Amendment Bill Poses Imminent Threa...
# 303                    Transgender Ideology Hurts Kids
#
#                                       author       date  \
# 0                     [Sarah Parshall Perry] 2024-12-13
# 1     [Paul J. Larkin, Sarah Parshall Perry] 2025-02-19
# 2                     [Sarah Parshall Perry] 2025-03-20
# 3    [Thomas  Jipping, Sarah Parshall Perry] 2024-10-23
# 4                     [Sarah Parshall Perry] 2025-02-27
# ..                                       ...        ...
# 299                      [Elizabeth  Fender] 2016-06-02
# 300                       [Rebecca  Hagelin] 2005-02-11
# 301                [Ryan T. Anderson, Ph.D.] 2012-12-13
# 302                          [Monica  Burke] 2018-04-24
# 303                [Ryan T. Anderson, Ph.D.] 2018-01-30
#
#                                                    url  \
# 0    https://www.heritage.org/gender/commentary/uni...
# 1    https://www.heritage.org/gender/commentary/tru...
# 2    https://www.heritage.org/gender/commentary/sor...
# 3    https://www.heritage.org/gender/commentary/wis...
# 4    https://www.heritage.org/gender/commentary/fol...
# ..                                                 ...
# 299  https://www.heritage.org/gender/commentary/the...
# 300  https://www.heritage.org/marriage-and-family/c...
# 301  https://www.heritage.org/marriage-and-family/c...
# 302  https://www.heritage.org/civil-society/comment...
# 303  https://www.heritage.org/gender/commentary/tra...
#
#                                              takeaways  \
# 0    [Tennessee is one of 26 states that have enact...
# 1    [They claim the president’s directive prohibit...
# 2    [Under the last presidential administration, p...
# 3    [Schools are generally in charge of matters su...
# 4    [Hurson’s decision halts the directives of Pre...
# ..                                                 ...
# 299                                                 []
# 300                                                 []
# 301                                                 []
# 302                                                 []
# 303                                                 []
#
#                                                   text
# 0    On Wednesday, December 3, the U.S. Supreme Cou...
# 1    In two short weeks, President Donald Trump has...
# 2    Under the last presidential administration, pr...
# 3    The Supreme Court has said that parents’ right...
# 4    It’s difficult to envision a more dizzying exe...
# ..                                                 ...
# 299  Between North Carolina’s bathroom law and Pres...
# 300  Parents, does the school your children attend ...
# 301  Yesterday’s post explained government’s policy...
# 302  A new bill in California claims to protect LGB...
# 303  Properly understanding sex, gender, gender ide...
#
# [304 rows x 6 columns]

# %%
## exploring our data

df.sample(10)
# Out:
#                                                  title  \
# 185                                    Rachel Greszler
# 273  Transgender Ideology Is Riddled With Contradic...
# 195  Women, Children, and Religious Americans Are N...
# 50                                        Grace Melton
# 49   Trans Athlete Injures Multiple Girls, Forcing ...
# 89   Respecting Constitution Requires Acknowledging...
# 65                                      Jack Fitzhenry
# 237  Newly Proposed Transgender Policies Could Harm...
# 98   Lawmakers, Let Parents Have a Say in Their Chi...
# 251  Why Gender Dysphoria Must Remain a Bar to Mili...
#
#                                   author       date  \
# 185                                   []        NaT
# 273            [Ryan T. Anderson, Ph.D.] 2018-02-09
# 195               [Sarah Parshall Perry] 2021-02-25
# 50                                    []        NaT
# 49                [Sarah Parshall Perry] 2024-03-05
# 89                     [Thomas  Jipping] 2023-02-23
# 65                                    []        NaT
# 237        [Emilie  Kao, Nicholas  Marr] 2019-07-02
# 98   [Jonathan  Butcher, Jason  Bedrick] 2023-01-27
# 251                     [Thomas  Spoehr] 2019-02-25
#
#                                                    url  \
# 185     https://www.heritage.org/staff/rachel-greszler
# 273  https://www.heritage.org/gender/commentary/tra...
# 195  https://www.heritage.org/religious-liberty/com...
# 50         https://www.heritage.org/staff/grace-melton
# 49   https://www.heritage.org/gender/commentary/tra...
# 89   https://www.heritage.org/the-constitution/comm...
# 65       https://www.heritage.org/staff/jack-fitzhenry
# 237  https://www.heritage.org/gender/commentary/new...
# 98   https://www.heritage.org/gender/commentary/law...
# 251  https://www.heritage.org/defense/commentary/wh...
#
#                                              takeaways  \
# 185                                                 []
# 273                                                 []
# 195  [The Act adds “sex” to some titles like “publi...
# 50                                                  []
# 49   [To watch the patent discrimination extant in ...
# 89   [When Congress proposed the Equal Rights Amend...
# 65                                                  []
# 237                                                 []
# 98   [Education bureaucrats are “socially affirming...
# 251  [Individuals with gender dysphoria experience ...
#
#                                                   text
# 185  As a Senior Research Fellow in the Roe Institu...
# 273  People say that we live in a postmodern age th...
# 195  President Joe Biden, only the second Catholic ...
# 50   Grace Melton is a Senior Associate for interna...
# 49   Third-wave feminists have set women back 50 ye...
# 89   When Congress proposed the Equal Rights Amendm...
# 65   Jack Fitzhenry is a Legal Fellow in the Edwin ...
# 237  Congress is right when it considers policies t...
# 98   Education bureaucrats are “socially affirming”...
# 251  In normal usage, “discrimination” is an ugly w...

# %%
df.columns
# Out:
# Index(['title', 'author', 'date', 'url', 'takeaways', 'text'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      304 non-null    object
#  1   author     304 non-null    object
#  2   date       279 non-null    datetime64[ns]
#  3   url        304 non-null    object
#  4   takeaways  304 non-null    object
#  5   text       304 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 14.4+ KB

# %%
## how to access a column

df['text']
# Out:
# 0      On Wednesday, December 3, the U.S. Supreme Cou...
# 1      In two short weeks, President Donald Trump has...
# 2      Under the last presidential administration, pr...
# 3      The Supreme Court has said that parents’ right...
# 4      It’s difficult to envision a more dizzying exe...
#                              ...
# 299    Between North Carolina’s bathroom law and Pres...
# 300    Parents, does the school your children attend ...
# 301    Yesterday’s post explained government’s policy...
# 302    A new bill in California claims to protect LGB...
# 303    Properly understanding sex, gender, gender ide...
# Name: text, Length: 304, dtype: object

# %%
df['author']
# Out:
# 0                       [Sarah Parshall Perry]
# 1       [Paul J. Larkin, Sarah Parshall Perry]
# 2                       [Sarah Parshall Perry]
# 3      [Thomas  Jipping, Sarah Parshall Perry]
# 4                       [Sarah Parshall Perry]
#                         ...
# 299                        [Elizabeth  Fender]
# 300                         [Rebecca  Hagelin]
# 301                  [Ryan T. Anderson, Ph.D.]
# 302                            [Monica  Burke]
# 303                  [Ryan T. Anderson, Ph.D.]
# Name: author, Length: 304, dtype: object

# %%
## cleaning:

## what do we want to do with the data?
## what kind of data do we have? Check each column's data type.
## what kind of data do we need?

# %%
## how to access a column?
## how to access a row from that column?

type(df['title'][0])
# Out:
# str

# %%
type(df['author'][0])
# Out:
# list

# %%
type(df['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
## the type of data that we have determines what we can do with it.

# print the data type of each column by checking the first element of each column
for col in df.columns:
    print(f"{col}: {type(df[col][0])}")
# Out:
# title: <class 'str'>
# author: <class 'list'>
# date: <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# url: <class 'str'>
# takeaways: <class 'list'>
# text: <class 'str'>

# %%
## challenge: 

## we want to remove rows that have an empty value in the 'author' column.

# %%
## from coplit:

import numpy as np

## uses replace() function -- very useful for cleaning
df['author'].replace('', np.nan, inplace=True)
df = df.dropna(subset=['author'])
# Out:
# /var/folders/z6/8hbw1n6n3dq2jdw3_zjysj5sws21gh/T/ipykernel_73368/546168888.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['author'].replace('', np.nan, inplace=True)

# %%
df.sample(20)
# Out:
#                                                  title  \
# 301              Monogamy, Exclusivity and Permanence?
# 97   Two Recent Supreme Court Decisions Give Pro-Li...
# 31   Even the Census Bureau Is Trying To Promote Ra...
# 119  Biden’s Push for “Gender-Affirming Care” Betra...
# 173  Economic Freedom Best Path to Women’s Equality...
# 206  Debate the Equality Act, but Tell the Truth Ab...
# 166  Biden’s Latest Proposal Would Force Insurers t...
# 68   Michigan’s Hate Crime Law Is Unconstitutional....
# 280  Court Should Reject Obama's Radical Social Exp...
# 21                                Illusion vs. Reality
# 45   College Admissions Officers Use Pronouns to Gi...
# 3    Wisconsin Public Schools’ Gender Policies Shut...
# 201        4 Ways the Equality Act Would Harm Children
# 244                Equality Act Harms American Freedom
# 139  Biden Administration Holds School Lunches Host...
# 74                            What Is Gender Ideology?
# 118  Federal Judge Blocks Biden’s Attempt to Reinte...
# 13                      Persecuted Behind Closed Doors
# 154  Will Left’s Gender Agenda Fall Flat With Minor...
# 278  Pentagon’s New Transgender Policy Strikes Righ...
#
#                                           author       date  \
# 301                    [Ryan T. Anderson, Ph.D.] 2012-12-13
# 97                             [Thomas  Jipping] 2023-01-30
# 31                              [Mike  Gonzalez] 2023-11-17
# 119                              [Tim  Doescher] 2022-07-07
# 173           [Anthony B. Kim, Giovanna  Milano] 2021-08-03
# 206                            [Thomas  Jipping] 2021-03-23
# 166        [Jay W. Richards, PhD, Jared  Eckert] 2022-02-07
# 68                        [Sarah Parshall Perry] 2023-07-19
# 280               [Roger  Severino, Jim  DeMint] 2016-12-14
# 21                           [Jonathan  Butcher] 2024-05-31
# 45                         [GianCarlo  Canaparo] 2023-10-02
# 3        [Thomas  Jipping, Sarah Parshall Perry] 2024-10-23
# 201                              [Andrea  Jones] 2020-10-01
# 244                              [Monica  Burke] 2019-05-20
# 139                       [Sarah Parshall Perry] 2022-06-13
# 74                        [Jay W. Richards, PhD] 2023-07-07
# 118  [GianCarlo  Canaparo, Sarah Parshall Perry] 2022-07-21
# 13                                [Emma  Waters] 2024-10-01
# 154                       [Jay W. Richards, PhD] 2022-01-18
# 278                             [Thomas  Spoehr] 2018-06-07
#
#                                                    url  \
# 301  https://www.heritage.org/marriage-and-family/c...
# 97   https://www.heritage.org/courts/commentary/two...
# 31   https://www.heritage.org/gender/commentary/eve...
# 119  https://www.heritage.org/gender/commentary/bid...
# 173  https://www.heritage.org/gender/commentary/eco...
# 206  https://www.heritage.org/religious-liberty/com...
# 166  https://www.heritage.org/gender/commentary/bid...
# 68   https://www.heritage.org/gender/commentary/mic...
# 280  https://www.heritage.org/gender/commentary/cou...
# 21   https://www.heritage.org/gender/commentary/ill...
# 45   https://www.heritage.org/gender/commentary/col...
# 3    https://www.heritage.org/gender/commentary/wis...
# 201  https://www.heritage.org/gender/commentary/4-w...
# 244  https://www.heritage.org/gender/commentary/equ...
# 139  https://www.heritage.org/gender/commentary/bid...
# 74   https://www.heritage.org/gender/commentary/wha...
# 118  https://www.heritage.org/government-regulation...
# 13   https://www.heritage.org/religious-liberty/com...
# 154  https://www.heritage.org/gender/commentary/wil...
# 278  https://www.heritage.org/defense/commentary/pe...
#
#                                              takeaways  \
# 301                                                 []
# 97   [Overruling Roe v. Wade will not stop abortion...
# 31   [The Census Bureau is asking Congress for $10 ...
# 119  [We need to help parents protect their childre...
# 173  [The best environment to promote equality is a...
# 206  [Each of us has the right to be free from all ...
# 166  [The U. S. Department of Health and Human Serv...
# 68   [HB 4474 would make it a felony hate crime off...
# 280                                                 []
# 21   [President Joe Biden’s administration has appr...
# 45   [Responses to pronoun users were “more positiv...
# 3    [Schools are generally in charge of matters su...
# 201  [The Equality Act’s impact would be felt in a ...
# 244                                                 []
# 139  [Such a change will, among other things, open ...
# 74   [Gender ideology is the source of the belief t...
# 118  [Any regulated entity would be foolish to igno...
# 13   [The religious persecution of women prioritize...
# 154  [It’s doubtful that many, let alone most, mino...
# 278  [Kennedy accuses President Donald Trump’s Pent...
#
#                                                   text
# 301  Yesterday’s post explained government’s policy...
# 97   Two recent court decisions, on abortion and ge...
# 31   The Census Bureau is asking Congress for $10 m...
# 119  Now that the U.S. Supreme Court has overturned...
# 173  Women’s battle for equal rights under the law ...
# 206  The issues raised by the Equality Act are seri...
# 166  President Joe Biden has sought to inject gende...
# 68   Last month, the Michigan House passed Bill 447...
# 280  Once it had convinced the Supreme Court to red...
# 21   “Sex” is getting a makeover. President Joe Bid...
# 45   Why are so many of our institutions captured b...
# 3    The Supreme Court has said that parents’ right...
# 201  Former Vice President Joe Biden, the Democrati...
# 244  The Equality Act promises to promote tolerance...
# 139  There’s been plenty of sturm und drang over th...
# 74   Recently, I received separate inquiries from r...
# 118  How do you solve a problem like a rogue agency...
# 13   When it comes to the kind of religious persecu...
# 154  A new, glossy messaging document reveals the p...
# 278  More than 100 lawmakers have signed a letter c...
