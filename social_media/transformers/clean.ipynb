# %%
import pandas as pd
df = pd.read_json('test.json')

# %%
df
# Out:
#                                                  title  \
# 0    Biden-Harris DOJ Prosecutor Targets Trans Whis...
# 1    Wisconsin Public Schools’ Gender Policies Shut...
# 2    United States v. Skrmetti: Oral Arguments Indi...
# 3    Trump’s Transgender Orders Are Well Within Exe...
# 4                                       Follow the Law
# ..                                                 ...
# 299                                   Elizabeth Fender
# 300                                    Parents Beware!
# 301                              Buyer Beware of CEDAW
# 302  Why Any Male Student Should Think Twice Before...
# 303  The Problems With CNN Poll Showing Opposition ...
#
#                                             author       date  \
# 0    [Hans A. von Spakovsky, Sarah Parshall Perry] 2024-11-07
# 1          [Thomas  Jipping, Sarah Parshall Perry] 2024-10-23
# 2                           [Sarah Parshall Perry] 2024-12-13
# 3           [Paul J. Larkin, Sarah Parshall Perry] 2025-02-19
# 4                           [Sarah Parshall Perry] 2025-02-27
# ..                                             ...        ...
# 299                                             []        NaT
# 300                             [Rebecca  Hagelin] 2005-02-11
# 301                                             [] 2002-08-28
# 302                        [Hans A. von Spakovsky] 2015-08-18
# 303                            [Elizabeth  Fender] 2016-06-02
#
#                                                    url  \
# 0    https://www.heritage.org/courts/commentary/bid...
# 1    https://www.heritage.org/gender/commentary/wis...
# 2    https://www.heritage.org/gender/commentary/uni...
# 3    https://www.heritage.org/gender/commentary/tru...
# 4    https://www.heritage.org/gender/commentary/fol...
# ..                                                 ...
# 299    https://www.heritage.org/staff/elizabeth-fender
# 300  https://www.heritage.org/marriage-and-family/c...
# 301  https://www.heritage.org/the-constitution/comm...
# 302  https://www.heritage.org/gender/commentary/why...
# 303  https://www.heritage.org/gender/commentary/the...
#
#                                              takeaways  \
# 0    [The weaponization of the U.S. Department of J...
# 1    [Schools are generally in charge of matters su...
# 2    [Tennessee is one of 26 states that have enact...
# 3    [They claim the president’s directive prohibit...
# 4    [Hurson’s decision halts the directives of Pre...
# ..                                                 ...
# 299                                                 []
# 300                                                 []
# 301                                                 []
# 302                                                 []
# 303                                                 []
#
#                                                   text
# 0    The weaponization of the U.S. Department of Ju...
# 1    The Supreme Court has said that parents’ right...
# 2    On Wednesday, December 3, the U.S. Supreme Cou...
# 3    In two short weeks, President Donald Trump has...
# 4    It’s difficult to envision a more dizzying exe...
# ..                                                 ...
# 299  Elizabeth Fender is the Senior Brand Advisor f...
# 300  Parents, does the school your children attend ...
# 301  In late July, when the Senate Foreign Relation...
# 302  This should terrify any parent whose son is ab...
# 303  Between North Carolina’s bathroom law and Pres...
#
# [304 rows x 6 columns]

# %%
## exploring our data

df.sample(10)
# Out:
#                                                  title  \
# 262           Massachusetts Can Protect Women and Kids
# 142  New Jersey Schools Want To Talk to Kids About ...
# 300                                    Parents Beware!
# 96                                  Diplomacy in Drag?
# 35         Make Miss Universe Pageant All-Female Again
# 248     Equality Act Would Create Inequality for Women
# 209  Bill Would Ban Gender Reassignment Procedures ...
# 13                       A Feminine Form of Resistance
# 47   Massachusetts’ Religious Bigotry Leaves Foster...
# 255     7 Reasons Why the Equality Act Is Anything But
#
#                               author       date  \
# 262                  [Monica  Burke] 2018-11-06
# 142              [Jonathan  Butcher] 2022-04-19
# 300               [Rebecca  Hagelin] 2005-02-11
# 96                [Simon  Hankinson] 2023-01-12
# 35                   [Peter  Parisi] 2023-11-20
# 248                    [Emilie  Kao] 2019-03-27
# 209                  [Andrea  Jones] 2020-08-24
# 13                    [Emma  Waters] 2024-08-26
# 47   [Thomas  Jipping, Katie  Blair] 2023-09-11
# 255                  [Monica  Burke] 2019-03-14
#
#                                                    url  \
# 262  https://www.heritage.org/gender/commentary/mas...
# 142  https://www.heritage.org/education/commentary/...
# 300  https://www.heritage.org/marriage-and-family/c...
# 96   https://www.heritage.org/gender/commentary/dip...
# 35   https://www.heritage.org/gender/commentary/mak...
# 248  https://www.heritage.org/gender/commentary/equ...
# 209  https://www.heritage.org/gender/commentary/bil...
# 13   https://www.heritage.org/marriage-and-family/c...
# 47   https://www.heritage.org/gender/commentary/mas...
# 255  https://www.heritage.org/gender/commentary/7-r...
#
#                                              takeaways  \
# 262  [The law in question, passed in 2016, changed ...
# 142  [This fall, New Jersey’s department of educati...
# 300                                                 []
# 96   [Leftist political appointees now in charge at...
# 35   [How humiliating and disheartening must it be ...
# 248  [By embracing the ideology of “gender identity...
# 209  [The U.K.’s minister for women and equalities ...
# 13   [The role of women in political fights is a ta...
# 47   [What could possibly be more important than fi...
# 255                                                 []
#
#                                                   text
# 262  This election cycle, there’s a question on the...
# 142  Helping your child with math homework after sc...
# 300  Parents, does the school your children attend ...
# 96   Who would have thought we’d need a bill “To Ba...
# 35   How humiliating and disheartening must it be f...
# 248  How ironic that House Speaker Nancy Pelosi int...
# 209  The BBC reported back in March on a lawsuit ag...
# 13   The role of women in political fights is a tal...
# 47   Religious freedom, Congress said unanimously i...
# 255  Most Americans don’t want a nationwide bathroo...

# %%
df.columns
# Out:
# Index(['title', 'author', 'date', 'url', 'takeaways', 'text'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      304 non-null    object
#  1   author     304 non-null    object
#  2   date       279 non-null    datetime64[ns]
#  3   url        304 non-null    object
#  4   takeaways  304 non-null    object
#  5   text       304 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 14.4+ KB

# %%
## how to access a column

df['text']
# Out:
# 0      On Wednesday, December 3, the U.S. Supreme Cou...
# 1      In two short weeks, President Donald Trump has...
# 2      Under the last presidential administration, pr...
# 3      The Supreme Court has said that parents’ right...
# 4      It’s difficult to envision a more dizzying exe...
#                              ...
# 299    Between North Carolina’s bathroom law and Pres...
# 300    Parents, does the school your children attend ...
# 301    Yesterday’s post explained government’s policy...
# 302    A new bill in California claims to protect LGB...
# 303    Properly understanding sex, gender, gender ide...
# Name: text, Length: 304, dtype: object

# %%
df['author']
# Out:
# 0      [Hans A. von Spakovsky, Sarah Parshall Perry]
# 1            [Thomas  Jipping, Sarah Parshall Perry]
# 2                             [Sarah Parshall Perry]
# 3             [Paul J. Larkin, Sarah Parshall Perry]
# 4                             [Sarah Parshall Perry]
#                            ...
# 299                                               []
# 300                               [Rebecca  Hagelin]
# 301                                               []
# 302                          [Hans A. von Spakovsky]
# 303                              [Elizabeth  Fender]
# Name: author, Length: 304, dtype: object

# %%
## cleaning:

## what do we want to do with the data?
## what kind of data do we have? Check each column's data type.
## what kind of data do we need?

# %%
## how to access a column?
## how to access a row from that column?

type(df['title'][0])
# Out:
# str

# %%
type(df['author'][0])
# Out:
# list

# %%
type(df['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
## the type of data that we have determines what we can do with it.

# print the data type of each column by checking the first element of each column
for col in df.columns:
    print(f"{col}: {type(df[col][0])}")
# Out:
# title: <class 'str'>
# author: <class 'list'>
# date: <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# url: <class 'str'>
# takeaways: <class 'list'>
# text: <class 'str'>

# %%
## challenge: 

## we want to remove rows that have an empty value in the 'author' column.

# %%
## from coplit:

import numpy as np

## uses replace() function -- very useful for cleaning
df['author'].replace('', np.nan, inplace=True)
df = df.dropna(subset=['author'])
# Out:
# /var/folders/z6/8hbw1n6n3dq2jdw3_zjysj5sws21gh/T/ipykernel_868/2213434441.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['author'].replace('', np.nan, inplace=True)

# %%
# Remove rows where 'date' is NaT
df = df.dropna(subset=['date'])

# %%
df.sample(20)
# Out:
#                                                  title  \
# 28                   Feminism: Something To Talk About
# 14   Gender Activists to Pennsylvania Parents: We’l...
# 245  A Closer Read of the “Gender Wage Gap” Tells a...
# 77   Judge Misreads Supreme Court in Ruling Boy’s “...
# 269  Why the LGBT Alliance Could Be on the Brink of...
# 135  Does “Gender-Affirming Care” For Trans Kids Ac...
# 89   Radical Agenda Eclipses Women at the U.N.’s Co...
# 68   Planned Parenthood Taxpayer Funding Up; Aborti...
# 221          Compelled Speech Is Hitting Close to Home
# 155  Democrats Erase Women Through Budget “Reconcil...
# 140  Lia Thomas Was Just the Beginning. Biden Admin...
# 183  Young Children Are Being Targeted With Sexual ...
# 291  Just Because Liberals Call Something ‘Discrimi...
# 101  If You Want Our Help, You Must Accept Our Gend...
# 19   School Gender Policies Harm Students and Viola...
# 231  Males Don’t Belong in Women’s Sports—Even If T...
# 58            Former Teammate of Lia Thomas Speaks Out
# 214  DoD’s Transgender Entrance Policy Exists for a...
# 280  A New York Times Writer’s Reckless Hit Piece o...
# 254  Google’s Internal Audit Bucks the Narrative on...
#
#                                       author       date  \
# 28                          [Brenda  Hafera] 2024-06-14
# 14   [Thomas  Jipping, Sarah Parshall Perry] 2024-10-03
# 245                       [Rachel  Greszler] 2019-04-22
# 77                    [Sarah Parshall Perry] 2023-06-26
# 269         [Spencer  McCloy, Monica  Burke] 2018-07-27
# 135                     [Jay P. Greene, PhD] 2022-06-15
# 89                           [Grace  Melton] 2023-03-20
# 68                         [Melanie  Israel] 2023-06-13
# 221            [Andrea  Jones, Alex  Richey] 2020-02-04
# 155    [Jay W. Richards, PhD, Jared  Eckert] 2021-10-15
# 140     [Sarah Parshall Perry, Abby  Kassal] 2022-04-11
# 183          [Jared  Eckert, Makenna  McCoy] 2021-06-11
# 291                [Ryan T. Anderson, Ph.D.] 2017-03-02
# 101                          [Grace  Melton] 2023-02-16
# 19                         [Thomas  Jipping] 2024-04-16
# 231           [Andrea  Jones, Clare  Hepler] 2019-11-27
# 58                   [Kevin D. Roberts, PhD] 2023-08-16
# 214                         [Thomas  Spoehr] 2020-07-14
# 280                [Ryan T. Anderson, Ph.D.] 2018-02-28
# 254                       [Rachel  Greszler] 2019-03-05
#
#                                                    url  \
# 28   https://www.heritage.org/civil-society/comment...
# 14   https://www.heritage.org/gender/commentary/gen...
# 245  https://www.heritage.org/gender/commentary/clo...
# 77   https://www.heritage.org/gender/commentary/jud...
# 269  https://www.heritage.org/gender/commentary/why...
# 135  https://www.heritage.org/gender/commentary/doe...
# 89   https://www.heritage.org/gender/commentary/rad...
# 68   https://www.heritage.org/life/commentary/plann...
# 221  https://www.heritage.org/gender/commentary/com...
# 155  https://www.heritage.org/gender/commentary/dem...
# 140  https://www.heritage.org/gender/commentary/lia...
# 183  https://www.heritage.org/marriage-and-family/c...
# 291  https://www.heritage.org/gender/commentary/jus...
# 101  https://www.heritage.org/gender/commentary/if-...
# 19   https://www.heritage.org/education/commentary/...
# 231  https://www.heritage.org/gender/commentary/mal...
# 58   https://www.heritage.org/gender/commentary/for...
# 214  https://www.heritage.org/gender/commentary/dod...
# 280  https://www.heritage.org/gender/commentary/new...
# 254  https://www.heritage.org/jobs-and-labor/commen...
#
#                                              takeaways  \
# 28   [When many criticize feminism, they are really...
# 14   [Nearly 1,100 school districts across the coun...
# 245                                                 []
# 77   [Score one for the woke scolds, who now get to...
# 269  [A group of eight lesbians interrupted the par...
# 135  [Political abuse of science is emerging again ...
# 89   [As usual, abortion and gender ideology are co...
# 68   [Taxpayer funding is at an all-time high and a...
# 221  [“1984” is becoming more and more prescient by...
# 155  [The trajectory is unmistakable: Whenever feas...
# 140  [Women are the clear losers—finding themselves...
# 183  [As this year’s LGBT+ Pride Month has shown, y...
# 291  [Liberals are calling anything they dislike “d...
# 101  [President Biden is directing the full financi...
# 19   [The centerpiece of these policies is a studen...
# 231  [Fair competition in women’s sports remains un...
# 58                                                  []
# 214  [In deployed situations, a constant flow of me...
# 280  [We lose the ability to effectively call out b...
# 254                                                 []
#
#                                                   text
# 28   I have little patience for Simone de Beauvoir ...
# 14   If you’re the parent of a child in a Pennsylva...
# 245  Women can’t seem to get a break. They not only...
# 77   Score one for the woke scolds, who now get to ...
# 269  Events at the July 7 Pride in London parade re...
# 135  When faced with divisive political arguments, ...
# 89   While the United Nations is in the midst of it...
# 68   Planned Parenthood’s 2021-2022 annual report i...
# 221  George Orwell wrote his dystopian novel “1984”...
# 155  According to Senate rules, a reconciliation pa...
# 140  This year marks the 50th anniversary of the pa...
# 183  Dating back to the 1860s, Americans celebrate ...
# 291  The biggest problem with current sexual orient...
# 101  The U.S. government is sparing no effort to sp...
# 19   Like others around the country, the Rockford, ...
# 231  Fair competition in women’s sports remains und...
# 58   In 2019, the University of Pennsylvania's swim...
# 214  Service in the U.S. armed forces is a privileg...
# 280  Anti-trans bigotry exists. It’s wrong, and we ...
# 254  Whether it’s the result of political pressure ...

# %%
# write df to new json file
df.to_json('cleaned.json', orient='records', lines=True)

# %%
# pull out "text" column
text = df['text']

# %%
#write text to a file called "text.txt"
with open('text.txt', 'w') as f:
    for line in text:
        f.write(line + '\n\n')
